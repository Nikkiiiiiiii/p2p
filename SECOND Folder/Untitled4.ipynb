# %%
import pandas as pd
import numpy as np

# Matplotlib and seaborn for visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/score.csv")

# %%
df['CreditRating'].value_counts()
# Out:
# A     7195754
# AA     667167
# HR     583117
# D       10197
# E        8806
# C        2534
# B        1271
# Name: CreditRating, dtype: int64

# %%
df8['CreditRating'].value_counts()
# Out:
# A     7195635
# HR     582938
# D        9827
# E        8149
# C        2408
# AA       2031
# B        1240
# Name: CreditRating, dtype: int64

# %%
df = df.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
df1 = df[df['ProjectStatus'].isin([1]) & df['CreditRating'].str.contains('HR')]

# %%
df1.to_csv("D:/Nikkidata/ren/csv/HR1.csv")

# %%
df2 = df[df['ProjectStatus'].isin([4]) & df['CreditRating'].str.contains('C')]

# %%
df2.to_csv("D:/Nikkidata/ren/csv/C4.csv")

# %%
df3 = df[df['CreditRating'].str.contains('AA')]

# %%
df3.to_csv("D:/Nikkidata/ren/csv/aa.csv")

# %%
df4 =df[df.CreditScore < 500]

# %%
df4 = df4[(df4.CreditScore > 209) & df4['CreditRating'].str.contains('AA')]

# %%
df4.to_csv("D:/Nikkidata/ren/csv/209AA.csv")

# %%
df4 = df[df['CreditRating'].str.contains('A') ]

# %%
df4.to_csv("D:/Nikkidata/ren/csv/A.csv")

# %%
df41 = df[(df.CreditScore < 210) & (df.CreditScore > 179) & df['CreditRating'].str.contains('A') ]

# %%
df42 = df41[~df41['CreditRating'].str.contains('AA') ]

# %%
df42.to_csv("D:/Nikkidata/ren/csv/180A.csv")

# %%
df5 = df[(df.CreditScore > 149) & df['CreditRating'].str.contains('B') & (df.CreditScore < 180) ]

# %%
df5.to_csv("D:/Nikkidata/ren/csv/150B.csv")

# %%
df6 = df[df['CreditRating'].str.contains('B')]

# %%
df6.to_csv("D:/Nikkidata/ren/csv/B.csv")

# %%
df7 = df[(df.CreditScore < 100) & df['CreditRating'].str.contains('HR') ]

# %%
df7.to_csv("D:/Nikkidata/ren/csv/HR100.csv")

# %%
df7 = df[df['CreditRating'].str.contains('HR') ]

# %%
df7.to_csv("D:/Nikkidata/ren/csv/HR.csv")

# %%
df5 = df[(df.CreditScore > 129) & df['CreditRating'].str.contains('C') & (df.CreditScore < 150) ]

# %%
df5.to_csv("D:/Nikkidata/ren/csv/C.csv")

# %%
df5 = df[(df.CreditScore > 109) & df['CreditRating'].str.contains('D') & (df.CreditScore < 130) ]

# %%
df5.to_csv("D:/Nikkidata/ren/csv/D.csv")

# %%
df5 = df[(df.CreditScore > 99) & df['CreditRating'].str.contains('E') & (df.CreditScore < 110) ]

# %%
df5.to_csv("D:/Nikkidata/ren/csv/E.csv")

# %%
df1 = pd.read_csv("D:/Nikkidata/ren/csv/209AA.csv")
df2 = pd.read_csv("D:/Nikkidata/ren/csv/180A.csv")
df3 = pd.read_csv("D:/Nikkidata/ren/csv/150B.csv")
df4 = pd.read_csv("D:/Nikkidata/ren/csv/C.csv")
df5 = pd.read_csv("D:/Nikkidata/ren/csv/D.csv")
df6 = pd.read_csv("D:/Nikkidata/ren/csv/E.csv")
df7 = pd.read_csv("D:/Nikkidata/ren/csv/HR100.csv")

frames = [df1,df2,df3,df4,df5,df6,df7]
all_csv = pd.concat(frames)
#合并7个csv文件

# %%
all_csv.to_csv("D:/Nikkidata/ren/csv/correctCreditScore.csv")

# %%
df8 = pd.read_csv("D:/Nikkidata/ren/csv/correctCreditScore.csv")

# %%
df8.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1     BidAmount           APR  \
# count  7.802228e+06  7.802228e+06  7.802228e+06  7.802228e+06
# mean   3.339889e+06  4.164129e+06  8.806802e+00  7.119019e+00
# std    2.184224e+06  2.470596e+06  2.327699e+00  1.830499e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.343964e+06  1.974852e+06  8.000000e+00  5.000000e+00
# 50%    3.294520e+06  4.136784e+06  1.000000e+01  8.000000e+00
# 75%    5.245077e+06  6.311269e+06  1.000000e+01  8.000000e+00
# max    7.195634e+06  8.468845e+06  1.000000e+01  1.000000e+01
#
#        RepaymentPeriod  ProjectStatus           Sex   CreditScore  \
# count     7.802228e+06   7.802228e+06  7.802228e+06  7.802228e+06
# mean      5.593097e+00   1.604384e+00  8.480084e+00  1.673896e+02
# std       2.851775e+00   6.256154e-01  2.299877e+00  4.416270e+01
# min       0.000000e+00   1.000000e+00  5.000000e+00 -9.900000e+01
# 25%       5.000000e+00   1.000000e+00  5.000000e+00  1.800000e+02
# ...

# %%
df8.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1     BidAmount           APR  \
# count  9.048051e+06  9.048051e+06  9.048051e+06  9.048051e+06
# mean   3.452201e+06  3.988168e+06  8.696036e+00  6.939072e+00
# std    2.447701e+06  2.546369e+06  2.360241e+00  1.985777e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.074710e+06  1.682808e+06  8.000000e+00  5.000000e+00
# 50%    3.336723e+06  3.944820e+06  1.000000e+01  8.000000e+00
# 75%    5.598736e+06  6.206832e+06  1.000000e+01  8.000000e+00
# max    7.860748e+06  8.468845e+06  1.000000e+01  1.000000e+01
#
#        RepaymentPeriod  ProjectStatus           Sex   CreditScore  \
# count     9.048051e+06   9.048051e+06  9.048051e+06  9.048051e+06
# mean      5.586105e+00   1.692201e+00  8.504220e+00  1.584018e+02
# std       2.800993e+00   6.873384e-01  2.289442e+00  5.621863e+01
# min       0.000000e+00   1.000000e+00  5.000000e+00 -9.900000e+01
# 25%       5.000000e+00   1.000000e+00  5.000000e+00  1.800000e+02
# ...

# %%
df42.describe()
# Out:
#           BidAmount           APR  RepaymentPeriod  ProjectStatus  \
# count  7.195635e+06  7.195635e+06     7.195635e+06   7.195635e+06
# mean   9.002661e+00  7.357044e+00     5.645895e+00   1.493065e+00
# std    2.196844e+00  1.530937e+00     2.857890e+00   5.011979e-01
# min    0.000000e+00  0.000000e+00     0.000000e+00   1.000000e+00
# 25%    1.000000e+01  5.000000e+00     5.000000e+00   1.000000e+00
# 50%    1.000000e+01  8.000000e+00     5.000000e+00   1.000000e+00
# 75%    1.000000e+01  8.000000e+00     8.000000e+00   2.000000e+00
# max    1.000000e+01  1.000000e+01     1.000000e+01   3.000000e+00
#
#                 Sex   CreditScore           Age     Education  MaritalStatus  \
# count  7.195635e+06  7.195635e+06  7.195635e+06  7.195635e+06   7.195635e+06
# mean   8.410753e+00  1.800037e+02  8.066723e+00  9.934213e-01   8.038444e+00
# std    2.328203e+00  1.387105e-01  1.036187e+00  2.437230e+00   2.729572e+00
# ...

# %%
df['CreditRating'].value_counts()
# Out:
# A     7195754
# AA     667167
# HR     583117
# D       10197
# E        8806
# C        2534
# B        1271
# Name: CreditRating, dtype: int64

# %%
df2.describe()
# Out:
#          Unnamed: 0     BidAmount           APR  RepaymentPeriod  \
# count  7.860749e+06  7.860749e+06  7.860749e+06     7.860749e+06
# mean   4.532138e+06  9.031194e+00  7.341560e+00     5.682437e+00
# std    2.280527e+06  2.135783e+00  1.519397e+00     2.803750e+00
# min    9.410000e+02  0.000000e+00  0.000000e+00     0.000000e+00
# 25%    2.573284e+06  1.000000e+01  5.000000e+00     5.000000e+00
# 50%    4.538471e+06  1.000000e+01  8.000000e+00     5.000000e+00
# 75%    6.503658e+06  1.000000e+01  8.000000e+00     8.000000e+00
# max    8.468845e+06  1.000000e+01  1.000000e+01     1.000000e+01
#
#        ProjectStatus           Sex   CreditScore           Age     Education  \
# count   7.860749e+06  7.860749e+06  7.860749e+06  7.860749e+06  7.860749e+06
# mean    1.502325e+00  8.383569e+00  1.800034e+02  8.079454e+00  9.206970e-01
# std     5.011433e-01  2.338655e+00  1.327165e-01  1.036525e+00  2.361305e+00
# ...

# %%
df3.describe()
# Out:
#           Unnamed: 0    BidAmount          APR  RepaymentPeriod  \
# count    1240.000000  1240.000000  1240.000000      1240.000000
# mean   153059.541935     6.046774     4.926613         6.662097
# std    192358.543484     3.207297     2.833889         2.611117
# min         7.000000     0.000000     0.000000         0.000000
# 25%     25461.250000     4.000000     3.000000         5.000000
# 50%     56666.000000     6.000000     3.000000         5.000000
# 75%    206692.750000     8.000000     8.000000        10.000000
# max    893515.000000    10.000000    10.000000        10.000000
#
#        ProjectStatus          Sex  CreditScore          Age    Education  \
# count    1240.000000  1240.000000  1240.000000  1240.000000  1240.000000
# mean        1.703226     9.197581   156.912097     8.962903     5.970968
# std         0.955333     1.836012     6.739918     0.873931     2.514358
# min         1.000000     5.000000   150.000000     6.000000     2.000000
# ...

# %%
df5.describe()
# Out:
#          BidAmount          APR  RepaymentPeriod  ProjectStatus          Sex  \
# count  2408.000000  2408.000000      2408.000000    2408.000000  2408.000000
# mean      6.583887     4.943937         6.360050       1.806478     9.379153
# std       3.077118     2.841721         2.699523       0.981300     1.649216
# min       0.000000     0.000000         0.000000       1.000000     5.000000
# 25%       4.000000     3.000000         5.000000       1.000000    10.000000
# 50%       8.000000     3.000000         5.000000       1.000000    10.000000
# 75%      10.000000     8.000000         8.000000       3.000000    10.000000
# max      10.000000    10.000000        10.000000       3.000000    10.000000
#
#        CreditScore          Age    Education  MaritalStatus  LoanNumbers  ...  \
# count  2408.000000  2408.000000  2408.000000    2408.000000  2408.000000  ...
# mean    138.107143     8.920266     5.696844       9.497508     7.245847  ...
# ...

# %%
df5.describe()
# Out:
#           Unnamed: 0    BidAmount          APR  RepaymentPeriod  \
# count    9827.000000  9827.000000  9827.000000      9827.000000
# mean   351004.969370     6.803094     4.968963         5.645467
# std    271068.766044     2.398647     2.833954         2.643111
# min         4.000000     0.000000     0.000000         0.000000
# 25%     79695.500000     6.000000     3.000000         3.000000
# 50%    309851.000000     8.000000     3.000000         5.000000
# 75%    584693.000000     8.000000     8.000000         8.000000
# max    898392.000000    10.000000    10.000000        10.000000
#
#        ProjectStatus          Sex  CreditScore          Age    Education  \
# count    9827.000000  9827.000000   9827.00000  9827.000000  9827.000000
# mean        1.824972     9.327363    116.61677     8.865269     5.578610
# std         0.984769     1.706177      5.26322     0.843168     2.428041
# min         1.000000     5.000000    110.00000     6.000000     0.000000
# ...

# %%
df6.describe()
# Out:
#           Unnamed: 0    BidAmount          APR  RepaymentPeriod  \
# count    8149.000000  8149.000000  8149.000000      8149.000000
# mean   476674.691741     6.769174     5.219291         5.351700
# std    231093.783065     2.224590     2.655547         2.531588
# min        58.000000     0.000000     0.000000         0.000000
# 25%    310234.000000     6.000000     3.000000         3.000000
# 50%    498090.000000     8.000000     5.000000         5.000000
# 75%    670386.000000     8.000000     8.000000         8.000000
# max    896858.000000    10.000000    10.000000        10.000000
#
#        ProjectStatus          Sex  CreditScore          Age    Education  \
# count    8149.000000  8149.000000  8149.000000  8149.000000  8149.000000
# mean        1.898883     9.229967   104.060253     8.802184     5.629402
# std         0.995491     1.804886     2.863346     0.794025     2.395965
# min         1.000000     5.000000   100.000000     6.000000     0.000000
# ...

# %%
df7.describe()
# Out:
#           Unnamed: 0      BidAmount            APR  RepaymentPeriod  \
# count  582938.000000  582938.000000  582938.000000    582938.000000
# mean   386725.892090       6.470791       4.254856         4.934912
# std    222057.863621       2.567713       2.557216         2.695308
# min        13.000000       0.000000       0.000000         0.000000
# 25%    196597.250000       6.000000       3.000000         3.000000
# 50%    390441.500000       6.000000       3.000000         5.000000
# 75%    575074.250000       8.000000       5.000000         5.000000
# max    896748.000000      10.000000      10.000000        10.000000
#
#        ProjectStatus            Sex    CreditScore            Age  \
# count  582938.000000  582938.000000  582938.000000  582938.000000
# mean        2.970376       9.303717      13.398204       8.610923
# std         0.280304       1.731072      17.704703       0.805986
# min         1.000000       5.000000     -99.000000       6.000000
# ...
