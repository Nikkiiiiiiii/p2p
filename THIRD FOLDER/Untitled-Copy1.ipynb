# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/RRDAIRight.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (8,14,17,20,46,52,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df['RemainningPeriods'].value_counts()
# Out:
# 0     1353145
# 8      727283
# 9      673715
# 5      611677
# 6      594651
# 3      573511
# 7      524967
# 2      447417
# 4      430607
# 12     378761
# 11     276041
# 10     230643
# 1      200734
# 24     177384
# 18      49116
# 36      41967
# 17      30541
# 13      29535
# 16      28901
# 15      28623
# 20      24809
# 22      22872
# 19      22426
# 21      21339
# 23      18442
# 25      14928
# 14      13517
# 26      12800
# 32      12263
# 27       9737
# 35       9148
# 34       9094
# 28       8120
# 31       7131
# 29       6869
# 30       6468
# 33       6370
# 48          3
# Name: RemainningPeriods, dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0            ID     ProjectNo     BidAmount           APR  \
# count  7.635555e+06  7.635555e+06  7.635555e+06  7.635555e+06  7.635555e+06
# mean   3.838821e+06  4.244058e+06  5.442263e+06  1.727137e+04  1.084154e+01
# std    2.210883e+06  2.437124e+06  2.749625e+06  4.172940e+04  1.311532e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  2.500000e+02  3.000000e+00
# 25%    1.927744e+06  2.110770e+06  3.313266e+06  1.000000e+03  1.020000e+01
# 50%    3.836634e+06  4.228359e+06  5.430856e+06  2.450000e+03  1.020000e+01
# 75%    5.745522e+06  6.358028e+06  7.705204e+06  6.000000e+03  1.200000e+01
# max    7.802559e+06  8.469232e+06  1.067800e+07  3.000000e+06  2.440000e+01
#
#        RepaymentPeriod       Bidders  RemainningPeriods  ProjectStatus  \
# count     7.635555e+06  7.635555e+06       7.635555e+06   7.635555e+06
# mean      2.197743e+00  1.938635e+01       6.625061e+00   1.578818e+00
# ...

# %%
# Using Edge Color for readability
plt.figure(figsize=(8,6))
x = df1['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram AA', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df2['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram A', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df3['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram B', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df4['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram C', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df5['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram D', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df6['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram E', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = df7['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram HR', ylabel='Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
x = dfn1['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram A', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = dfn2['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram B', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = dfn3['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram C', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = dfn4['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram D', ylabel='Frequency')
plt.show()

plt.figure(figsize=(8,6))
x = dfn5['APR']
plt.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
plt.gca().set(title='Histogram E', ylabel='Frequency')
plt.show()

# %%
fig= plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(4,2,1)
x = df1['APR']
ax1.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax1.set_title('Platform AA')
ax1.set_xlabel('APR')

ax2 = fig.add_subplot(4,2,2)
x = df2['APR']
ax2.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax2.set_title('A')
ax2.set_xlabel('APR')

ax3 = fig.add_subplot(4,2,3)
x = df3['APR']
ax3.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax3.set_title('B')
ax3.set_xlabel('APR')

ax4 = fig.add_subplot(4,2,4)
x = df4['APR']
ax4.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax4.set_title('C')
ax4.set_xlabel('APR')


ax5 = fig.add_subplot(4,2,5)
x = df5['APR']
ax5.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax5.set_title('D')
ax5.set_xlabel('APR')

ax6 = fig.add_subplot(4,2,6)
x = df6['APR']
ax6.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax6.set_title('E')
ax6.set_xlabel('APR')

ax7 = fig.add_subplot(4,2,7)
x = df7['APR']
ax7.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax7.set_title('HR')
ax7.set_xlabel('APR')
# Out:
# Text(0.5, 0, 'APR')

# %%
fig= plt.figure(figsize=(20,18))
ax1 = fig.add_subplot(3,2,1)
x = dfn1['APR']
ax1.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax1.set_title('Nikki A')
ax1.set_xlabel('APR')

ax2 = fig.add_subplot(3,2,2)
x = dfn2['APR']
ax2.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax2.set_title('B')
ax2.set_xlabel('APR')

ax3 = fig.add_subplot(3,2,3)
x = dfn3['APR']
ax3.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax3.set_title('C')
ax3.set_xlabel('APR')

ax4 = fig.add_subplot(3,2,4)
x = dfn4['APR']
ax4.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax4.set_title('D')
ax4.set_xlabel('APR')


ax5 = fig.add_subplot(3,2,5)
x = dfn5['APR']
ax5.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax5.set_title('E')
ax5.set_xlabel('APR')
# Out:
# Text(0.5, 0, 'APR')

# %%
fig= plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2,2,1)
x = df1['APR']
ax1.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax1.set_title('Platform AA')
ax1.set_xlabel('APR')

ax2 = fig.add_subplot(2,2,2)
x = df7['APR']
ax2.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax2.set_title('Platform HR')
ax2.set_xlabel('APR')

ax3 = fig.add_subplot(2,2,3)
x = dfn1['APR']
ax3.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax3.set_title('Nikki A')
ax3.set_xlabel('APR')

ax4 = fig.add_subplot(2,2,4)
x = dfn5['APR']
ax4.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax4.set_title('Nikki E')
ax4.set_xlabel('APR')
# Out:
# Text(0.5, 0, 'APR')

# %%
fig= plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(1,2,1)
x = df['CreditScore']
ax1.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax1.set_title('CreditScore')
ax1.set_xlabel('CreditScore')
ax1.set_ylabel('Number of Borrowers')
#ax1.gca().set(title='Histogram CreditScore', ylabel='Frequency')
#ax1.show()

ax2 = fig.add_subplot(1,2,2)
x = df['Nikkiscore1']
ax2.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax2.set_title('Nikkiscore1')
ax2.set_xlabel('Nikkiscore1')
ax2.set_ylabel('Number of Borrowers')
#ax2.gca().set(title='Histogram Nikkiscore1', ylabel='Frequency')
#ax2.show()

#add_subplot(总行数,总列数,该图位置)
# Out:
# Text(0, 0.5, 'Number of Borrowers')

# %%
fig= plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(1,2,1)
x = df['CreditRating']
ax1.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax1.set_title('CreditRating')
ax1.set_xlabel('CreditRating')
ax1.set_ylabel('Number of Borrowers')

ax2 = fig.add_subplot(1,2,2)
x = df['NikkiRating']
ax2.hist(x, bins=40, color='yellowgreen' , edgecolor="#6A9662")
ax2.set_title('NikkiRating')
ax2.set_xlabel('NikkiRating')
ax2.set_ylabel('Number of Borrowers')
# Out:
# Text(0, 0.5, 'Number of Borrowers')

# %%
from matplotlib.ticker import FuncFormatter
# Displaying values at the top of the Grouped Bar Chart using plt.text()
fig= plt.figure(figsize=(20,8))
x1 = df['CreditRating']
n, bins, patches = plt.hist(x1, bins=40, align='left', label='CreditRating',color='yellowgreen' , edgecolor="#6A9662")
for i in range(len(n)):
    plt.text(bins[i], n[i]*1.02, int(n[i]), fontsize=10, horizontalalignment="center")
plt.xlabel('CreditRating', fontweight='bold')
plt.ylabel('Number of Borrowers', fontweight='bold')
plt.title ('CreditRating')
plt.plot()
# Out:
# []

# %%
from matplotlib.ticker import FuncFormatter
# Displaying values at the top of the Grouped Bar Chart using plt.text()
fig= plt.figure(figsize=(20,8))
x2 = df['NikkiRating']
n, bins, patches = plt.hist(x2, bins=40, align='left', label='NikkiRating',color='yellowgreen' , edgecolor="#6A9662")
for i in range(len(n)):
    plt.text(bins[i], n[i]*1.02, int(n[i]), fontsize=10, horizontalalignment="center")
    #显示数值
plt.xlabel('NikkiRating', fontweight='bold')
plt.ylabel('Number of Borrowers', fontweight='bold')
plt.title ('NikkiRating')
plt.plot()
# Out:
# []

# %%
df["APR"].groupby('year').mean()

# %%
dfa = df[df['ProjectStatus'].isin([1])]

# %%
dfb = df[df['ProjectStatus'].isin([2])]

# %%
dfc = df[df['ProjectStatus'].isin([3])]

# %%
dfd = df[df['ProjectStatus'].isin([4])]

# %%
df1 = df[df['CreditRating'].isin([1])]

# %%
df2 = df[df['CreditRating'].isin([2])]

# %%
df3 = df[df['CreditRating'].isin([3])]

# %%
df4 = df[df['CreditRating'].isin([4])]

# %%
df5 = df[df['CreditRating'].isin([5])]

# %%
df6 = df[df['CreditRating'].isin([6])]

# %%
df7 = df[df['CreditRating'].isin([7])]

# %%
dfn1 = df[df['NikkiRating'].isin([1])]

# %%
dfn2 = df[df['NikkiRating'].isin([2])]

# %%
dfn3 = df[df['NikkiRating'].isin([3])]

# %%
dfn4 = df[df['NikkiRating'].isin([4])]

# %%
dfn5 = df[df['NikkiRating'].isin([5])]

# %%
AAPRN = df8['APR'].value_counts()

# %%
BAPRN = df9['APR'].value_counts()

# %%
CAPRN = df10['APR'].value_counts()

# %%
DAPRN = df11['APR'].value_counts()

# %%
HRAPRN = df12['APR'].value_counts()

# %%
AAPRN.to_csv("D:/Nikkidata/ren/csv/AAPRN.csv")

# %%
BAPRN.to_csv("D:/Nikkidata/ren/csv/BAPRN.csv")

# %%
CAPRN.to_csv("D:/Nikkidata/ren/csv/CAPRN.csv")

# %%
DAPRN.to_csv("D:/Nikkidata/ren/csv/DAPRN.csv")

# %%
HRAPRN.to_csv("D:/Nikkidata/ren/csv/HRAPRN.csv")

# %%
DAPR = df5['APR'].value_counts()

# %%
DAPR.to_csv("D:/Nikkidata/ren/csv/DAPR.csv")

# %%
HRAPR = df7['APR'].value_counts()

# %%
HRAPR.to_csv("D:/Nikkidata/ren/csv/HRAPR.csv")

# %%
plt.figure(figsize=(30,15))
import matplotlib.pyplot as plt
# Histogram of the CreditScore
from pylab import *
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist(dfa['year'], bins = 50, edgecolor = 'white');
plt.xlabel('year'); 
plt.ylabel('Number of Borrowers'); 
plt.legend()
plt.title('Distribution of the year');
plt.show()
plt.savefig('pubtime4.jpg', dpi=300)
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(30,15))
import matplotlib.pyplot as plt
# Histogram of the CreditScore
from pylab import *
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist(df['year'], bins = 50, edgecolor = 'white');
plt.xlabel('year'); 
plt.ylabel('Number of Borrowers'); 
plt.legend()
plt.title('Distribution of the year');
plt.show()
plt.savefig('pubtime4.jpg', dpi=300)
# Out:
# No handles with labels found to put in legend.

# %%
df['yearMonth'] = df['PubTime'].apply(lambda x:str(x)[:7])

# %%
df['year'] = df['PubTime'].apply(lambda x:str(x)[:4])

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAIRight.csv")

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/RRDAIRight.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (17,20,23,49,55,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# count  7.802560e+06  7.802560e+06    7.802560e+06      7.802560e+06
# mean   3.340026e+06  4.163363e+06    4.156362e+06      4.164313e+06
# std    2.184315e+06  2.470636e+06    2.470625e+06      2.470707e+06
# min    0.000000e+00  0.000000e+00    0.000000e+00      0.000000e+00
# 25%    1.344015e+06  1.973944e+06    1.966938e+06      1.974940e+06
# 50%    3.294654e+06  4.135960e+06    4.128954e+06      4.136956e+06
# 75%    5.245294e+06  6.310560e+06    6.303552e+06      6.311554e+06
# max    7.195934e+06  8.468236e+06    8.461229e+06      8.469231e+06
#
#                  ID     ProjectNo     BidAmount           APR  \
# count  7.802560e+06  7.802560e+06  7.802560e+06  7.802560e+06
# mean   4.164316e+06  5.339758e+06  1.806846e+04  1.087262e+01
# std    2.470717e+06  2.808193e+06  4.351739e+04  1.358969e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  3.000000e+00
# ...

# %%
to_drop =['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1','Unnamed: 0.1.1.1']
df.drop(to_drop, inplace = True , axis =1)

# %%
df = df[(df.Age < 70)]

# %%
df = df[(df.Age > 17)]

# %%
df['Education1'] = df.Education

# %%
edu_mapping={'高中或以下': 4,', 高中或以下': 4,'高中或以下,': 4,'大专, 高中或以下': 4,'高中或以下, 大专': 4,'高以下': 4,'高中或以下, 研究生或以上': 4,
             '大专': 6, ', 大专': 6,'大专,': 6,'专科': 6,'本科, 大专': 6,'大专, 短期周转': 6,'大专, 本科': 6,
             '本科': 8, ', 本科': 8,'本科,': 8,'本科, 本科': 8,
             '研究生或以上': 10, '研究生或以上,': 10, ', 研究生或以上': 10}
df['Education1'] = df['Education1'].map(edu_mapping)

# %%
df['CompanySize1'] = df.CompanySize

# %%
Com_mapping={'10人以下': 2,', 10人以下': 2,'10人以下, 10人以下': 2,'10人以下,': 2,'10人以下, 10人以下, 10人以下': 2,'10人以下 , 10人以下': 2,'10???': 2,'10人以下 ,': 2,
             '10-100人': 5, '10-100人, 10-100人': 5,', 10-100人': 5,'10-100人,': 5,'10-100?': 5,'10-100人 ,': 5,'10-100人,,': 5,
             '100-500人': 8, '100-500人, 100-500人': 8,', 100-500人': 8,'100-500人,': 8,'100-500人 ,': 8,
             '500人以上': 10, '500人以上, 500人以上': 10, ', 500人以上': 10, '500以上': 10, '500人以上,': 10, '500???': 10,'500人以上 ,': 10}
df['CompanySize1'] = df['CompanySize1'].map(Com_mapping)

# %%
df['WorkingHour1'] = df.WorkingHour

# %%
wor_mapping={'1年（含）以下': 2,', 1年（含）以下': 2,'1年（含）以下, 1年（含）以下': 2,'1年（含）以下,': 2,'1年（含）以下 ,': 2,'1??????': 2,
             '1-3年（含）': 5, '1-3年（含）, 1-3年（含）': 5,', 1-3年（含）': 5,'1-3年（含）,': 5,'1-3年（含） ,': 5,'1-3年（含）,,': 5,'1-3????': 5,
             '3-5年（含）': 8, '3-5年（含）, 3-5年（含）': 8,', 3-5年（含）': 8,'3-5年（含）,': 8,'3-5????': 8,
             '5年以上': 10, '5年以上, 5年以上': 10, ', 5年以上': 10, '5年以上,': 10, '5年以上 ,': 10, '5???': 10, '5年以上, 5年以上, 5年以上': 10}
df['WorkingHour1'] = df['WorkingHour1'].map(wor_mapping)

# %%
df['Income1'] = df.Income

# %%
Inc_mapping={'1000元以下': 1000, '1000元以下,': 1000, ',1000元以下': 1000, '1001-2000元, 1001-2000元,': 1000, ', 1001-2000元': 1000, 
             '2000元以下': 2000, '2000元以下': 2000, '2000元以下': 2000, '1001-2000元': 2000, 
             '2000-5000元': 3500, '2000-5000元 ,': 3500, '2000-5000元,': 3500, ', 2000-5000元': 3500, '2000-5000元, 2000-5000元': 3500, ', 2000-5000元': 3500, 
             '5000-10000元': 7500, '5000-10000?': 7500, '5000-10000元,': 7500, '5000-10000元 ,': 7500, '5000-10000元, 5000-10000元': 7500, ', 5000-10000元': 7500, 
             '10000-20000元': 15000,'10000-20000元,,': 15000,'10000-20000元?': 15000,'10000-20000元 ,': 15000,'10000-20000元,': 15000,', 10000-20000元': 15000,'10000-20000元, 10000-20000元': 15000,
             '20000-50000元': 35000,'20000-50000元,': 35000,'20000-50000元 ,': 35000,', 20000-50000元': 35000,'20000-50000元, 20000-50000元': 35000,
             '50000元以上': 50000, '50000元以上 ,': 50000, ', 50000元以上': 50000, '50000元以上, 50000元以上,': 50000}
df['Income1'] = df['Income1'].map(Inc_mapping)

# %%
df['BidIncomeRatio'] = df.BidAmount / df.Income1

# %%
df = df[(df.BidIncomeRatio > 0)]

# %%
df.BidIncomeRatio[df.BidIncomeRatio >= 0.7] = 0
df.BidIncomeRatio[(df.BidIncomeRatio > 0.0) & (df.BidIncomeRatio <= 0.3)] = 10
df.BidIncomeRatio[(df.BidIncomeRatio >= 0.6) & (df.BidIncomeRatio < 0.7)] = 3
df.BidIncomeRatio[(df.BidIncomeRatio >= 0.4) & (df.BidIncomeRatio < 0.6)] = 5
df.BidIncomeRatio[(df.BidIncomeRatio > 0.3) & (df.BidIncomeRatio < 0.4)] = 8
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/3782299722.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.BidIncomeRatio[(df.BidIncomeRatio > 0.0) & (df.BidIncomeRatio <= 0.3)] = 10
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/3782299722.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.BidIncomeRatio[(df.BidIncomeRatio >= 0.6) & (df.BidIncomeRatio < 0.7)] = 3
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/3782299722.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['Income1'] = df['Income1'].replace(1000.0, 0)
df['Income1'] = df['Income1'].replace(2000.0, 0)
df['Income1'] = df['Income1'].replace(3500.0, 0)
df['Income1'] = df['Income1'].replace(7500.0, 3)
df['Income1'] = df['Income1'].replace(15000.0, 6)
df['Income1'] = df['Income1'].replace(35000.0, 8)
df['Income1'] = df['Income1'].replace(50000.0, 10)

# %%
df['OthDebt1'] = df.OthDebt

# %%
Oth_mapping={'有': 0, '无': 1}
df['OthDebt1'] = df['OthDebt1'].map(Oth_mapping)

# %%
df['OthDebt1'] = df['OthDebt1'].replace(0, '-2')
df['OthDebt1'] = df['OthDebt1'].replace(1, '0')

# %%
sex_mapping={'男': 10, '女': 5}
df['Sex'] = df['Sex'].map(sex_mapping)

# %%
Mar_mapping={'丧偶': 0, '离异': 0, '未婚': 5, '已婚': 10}
df['MaritalStatus'] = df['MaritalStatus'].map(Mar_mapping)

# %%
Pro_mapping={'已还清': 1, '还款中': 2, '已流标': 3, '已垫付': 4}
df['ProjectStatus'] = df['ProjectStatus'].map(Pro_mapping)

# %%
df['houseLoan1'] = df.houseLoan

# %%
df['carLoan1'] = df.carLoan

# %%
df['houseLoan'].value_counts()
# Out:
# 无房贷      4416274
# 有房贷       559078
# False         32
# Name: houseLoan, dtype: int64

# %%
df['carLoan'].value_counts()
# Out:
# 无车贷      4619850
# 有车贷       346202
# False         32
# Name: carLoan, dtype: int64

# %%
Hou_mapping={'空': 0, '无房产': 0, '有房产': 2}
df['hasHouse'] = df['hasHouse'].map(Hou_mapping)
Loa_mapping={'无房贷': 0, 'False': 0, '有房贷': 1}
df['houseLoan1'] = df['houseLoan1'].map(Loa_mapping)
df['House'] = df.hasHouse + df.houseLoan1

# %%
car_mapping={'空': 0, '无车产': 0, '有车产': 2}
df['hasCar'] = df['hasCar'].map(car_mapping)
CLoa_mapping={'无车贷': 0, 'False': 0, '有车贷': 1}
df['carLoan1'] = df['carLoan1'].map(CLoa_mapping)
df['Car'] = df.hasCar + df.carLoan1

# %%
df['House'] = df['House'].replace(2.0, '10')
df['House'] = df['House'].replace(0.0, '2')
df['House'] = df['House'].replace(1.0, '0')
df['House'] = df['House'].replace(3.0, '5')
df['Car'] = df['Car'].replace(2.0, '10')
df['Car'] = df['Car'].replace(0.0, '2')
df['Car'] = df['Car'].replace(1.0, '0')
df['Car'] = df['Car'].replace(3.0, '5')

# %%
df.RepaymentPeriod[df.RepaymentPeriod > 24] = 0
df.RepaymentPeriod[(df.RepaymentPeriod >= 1) & (df.RepaymentPeriod <= 4)] = 4
df.RepaymentPeriod[(df.RepaymentPeriod >= 5) & (df.RepaymentPeriod <= 8)] = 3
df.RepaymentPeriod[(df.RepaymentPeriod >= 9) & (df.RepaymentPeriod  <= 12)] = 2
df.RepaymentPeriod[(df.RepaymentPeriod >= 13) & (df.RepaymentPeriod <=24)] = 1
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1507072587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.RepaymentPeriod[df.RepaymentPeriod > 24] = 0
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1507072587.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.RepaymentPeriod[(df.RepaymentPeriod >= 1) & (df.RepaymentPeriod <= 4)] = 4
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1507072587.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.Age[df.Age >= 60] = 5
df.Age[(df.Age >= 18) & (df.Age <= 25)] = 7
df.Age[(df.Age >= 51) & (df.Age <= 60)] = 7
df.Age[(df.Age >= 26) & (df.Age <= 30)] = 8
df.Age[(df.Age >= 46) & (df.Age <= 50)] = 8
df.Age[(df.Age >= 31) & (df.Age <= 35)] = 9
df.Age[(df.Age >= 41) & (df.Age <= 45)] = 9
df.Age[(df.Age >= 36) & (df.Age <= 40)] = 10
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1465141547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[df.Age >= 60] = 5
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1465141547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[(df.Age >= 18) & (df.Age <= 25)] = 7
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1465141547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['DefaultTimes1'] = 1.5*df.DefaultTimes

# %%
df['PaidOffTimes1'] = 1*df.PaidOffTimes

# %%
df['SeriousDefaultLoan1'] = 5*df.SeriousDefaultLoan

# %%
df = df.fillna(0)

# %%
df['Age'] = df['Age'].astype('int')
df['Education1'] = df['Education1'].astype('int')
df['MaritalStatus'] = df['MaritalStatus'].astype('int')
df['CompanySize1'] = df['CompanySize1'].astype('int')
df['WorkingHour1'] = df['WorkingHour1'].astype('int')
df['Income1'] = df['Income1'].astype('int')
df['BidIncomeRatio'] = df['BidIncomeRatio'].astype('int')
df['OthDebt1'] = df['OthDebt1'].astype('int')
df['House'] = df['House'].astype('int')
df['Car'] = df['Car'].astype('int')
df['DefaultTimes1'] = df['DefaultTimes1'].astype('int')

# %%
df['Nikkiscore1'] = 0.0447*df.Sex + 0.0572*df.Age + 0.0286*df.Education1 + 0.1097*df.MaritalStatus + 0.07*df.CompanySize1 + 0.14*df.WorkingHour1 + 0.1576*df.Income1 + 0.2466*df.BidIncomeRatio + 0.0765*df.House + 0.0691*df.Car - df.DefaultTimes1 + df.PaidOffTimes1 - df.SeriousDefaultLoan1 + df.RepaymentPeriod + df.OthDebt1

# %%
df['Nikkiscore2'] = 0.0532*df.Sex + 0.068*df.Age + 0.034*df.Education1 + 0.1304*df.MaritalStatus + 0.0476*df.CompanySize1 + 0.0953*df.WorkingHour1 + 0.1638*df.Income1 + 0.2563*df.BidIncomeRatio + 0.0795*df.House + 0.0718*df.Car - df.DefaultTimes1 + df.PaidOffTimes1 - df.SeriousDefaultLoan1 + df.RepaymentPeriod + df.OthDebt1

# %%
rat_mapping={'AA': 1, 'A': 2, 'B': 3, 'C': 4, 'D': 5, 'E': 6, 'HR': 7}
df['CreditRating'] = df['CreditRating'].map(rat_mapping)

# %%
df['NikkiRating'] = df.Nikkiscore1

# %%
df.NikkiRating[(df.NikkiRating > 0) & (df.NikkiRating <=5)] = 4
df.NikkiRating[(df.NikkiRating > 5) & (df.NikkiRating <= 10)] = 3
df.NikkiRating[df.NikkiRating <= 0] = 5
df.NikkiRating[(df.NikkiRating > 10) & (df.NikkiRating <= 15)] = 2
df.NikkiRating[(df.NikkiRating > 15) ] = 1
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1032518344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.NikkiRating[(df.NikkiRating > 0) & (df.NikkiRating <=5)] = 4
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1032518344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.NikkiRating[(df.NikkiRating > 5) & (df.NikkiRating <= 10)] = 3
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1032518344.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['NikkiRating'].value_counts()
# Out:
# 3.0    4212129
# 4.0    3087496
# 2.0     286684
# 1.0      35646
# 5.0      13600
# Name: NikkiRating, dtype: int64

# %%
df['CreditRating'].value_counts()
# Out:
# 2    7177080
# 7     434910
# 5       9803
# 6       8101
# 4       2395
# 1       2029
# 3       1237
# Name: CreditRating, dtype: int64

# %%
import matplotlib.pyplot as plt
# Histogram of the CreditScore
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist(df['CreditScore'], bins = 50, edgecolor = 'k');
plt.xlabel('score'); plt.ylabel('Number of Borrowers'); 
plt.legend()
plt.title('CreditScore Distribution');
plt.figure()
plt.hist(df['Nikkiscore1'].dropna(), bins = 50, edgecolor = 'k');
plt.legend()
plt.title('Nikkiscore1 Distribution');
plt.figure()
plt.hist(df['Nikkiscore2'].dropna(), bins = 50, edgecolor = 'k');
plt.legend()
plt.title('Nikkiscore2 Distribution');
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
df['Nikkiscore1']
# Out:
# 0          10.1401
# 1          33.2439
# 2           9.9080
# 3           7.1401
# 4          13.8147
#             ...
# 7802555    -0.5509
# 7802556    -1.7369
# 7802557     4.2087
# 7802558    -1.0121
# 7802559     5.7846
# Name: Nikkiscore1, Length: 7635555, dtype: float64

# %%
dff = df[df['ProjectStatus'].isin([4]) | df['ProjectStatus'].isin([1]) ]

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('NikkiRating', 'Nikkiscore1', 
           data = df, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('NikkiRating vs Nikkiscore1', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('NikkiRating', 'Nikkiscore1', 
           data = dff, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('NikkiRating vs Nikkiscore1', size = 24)
plt.legend()

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('CreditRating', 'Nikkiscore1', 
           data = df, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditRating vs Nikkiscore1', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('CreditRating', 'Nikkiscore2', 
           data = dff, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditRating vs Nikkiscore2', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('NikkiRating', 'APR', 
           data = df, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('NikkiRating vs APR', size = 24)
plt.legend()
plt.savefig('NikkiRatingAPR.jpg', dpi=300)
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6232/1502156152.py:12: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('NikkiRatingAPR.jpg', dpi=300)
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\pylabtools.py:137: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('NikkiRating', 'APR', 
           data = dff, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('NikkiRating vs APR', size = 24)
plt.legend()
plt.savefig('NikkiRatingAPR14.jpg', dpi=300)
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('Nikkiscore1', 'APR', 
           data = dff, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('Nikkiscore1 vs APR', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('Nikkiscore2', 'APR', 
           data = dff, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('Nikkiscore2 vs APR', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.to_csv("D:/Nikkidata/ren/csv/Nikkiscore12.csv")

# %%
df['Nikkiscore1'].value_counts()
# Out:
#  4.3347     108695
#  4.4729      91079
#  6.3347      77354
#  5.3347      75625
#  5.4729      71360
#              ...
#  3.4274          1
#  11.3394         1
#  11.0030         1
#  10.5837         1
# -1.8899          1
# Name: Nikkiscore1, Length: 71647, dtype: int64

# %%
a = df['Nikkiscore1'].value_counts()

# %%
a.to_csv("D:/Nikkidata/ren/csv/Nikkiscore1.csv")

# %%
df['Nikkiscore2'].value_counts()
# Out:
#  4.7144     104881
#  5.0170      87831
#  6.7144      74782
#  5.7144      72528
#  6.0170      68975
#              ...
# -28.0001         1
# -12.2060         1
# -22.2651         1
# -8.5685          1
# -1.0581          1
# Name: Nikkiscore2, Length: 100739, dtype: int64

# %%
b = df['Nikkiscore2'].value_counts()

# %%
b.to_csv("D:/Nikkidata/ren/csv/Nikkiscore2.csv")

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='PubTime',y='CreditScore',data=dff,hue='ProjectStatus')
plt.savefig('PubTimescore.jpg', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6232/4292754238.py in <module>
#       1 plt.figure(figsize=(30,15))
# ----> 2 sns.scatterplot(x='PubTime',y='CreditScore',data=dff,hue='ProjectStatus')
#       3 plt.savefig('PubTimescore.jpg', dpi=300)
#
# NameError: name 'dff' is not defined

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='PubTime',y='Nikkiscore1',data=dff,hue='ProjectStatus')

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='PubTime',y='Nikkiscore2',data=dff,hue='ProjectStatus')

# %%
df.count()
# Out:
# ID                    7802533
# ProjectNo             7802533
# CertifiMark           7802533
# ProjectTitle          7796020
# BorrowType            7801355
# BidAmount             7802533
# PubTime               7802533
# LoanTime              7199529
# APR                   7802533
# RepaymentPeriod       7802533
# GuaranteeWays         7802533
# PrerepaymentFee       7802533
# RepaymentWays         7802533
# RepaySource           6526289
# Bidders               7802533
# RemainningPeriods     7802533
# RepaymentDay          5844264
# BidProgress           7802533
# ProjectStatus         7802533
# CloseTime             1372007
# UserNo                7802533
# Nickname              7802470
# UserName              7802487
# Sex                   7802533
# Idno                  7802461
# CreditScore           7802533
# CreditRating          7802533
# Birthday              7802533
# Age                   7802533
# Education             7711783
# MaritalStatus         7179112
# ...

# %%
df1 = df[(df.Age > 65)]

# %%
df['MaritalStatus'].value_counts()
# Out:
# 未婚    3602887
# 已婚    3259112
# 离异     307175
# 丧偶       9938
# Name: MaritalStatus, dtype: int64

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/NewFolder2/RRDai.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7,13,16,19,45,51,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1 = df[(df.CreditScore == 0)]

# %%
df1.to_csv("D:/Nikkidata/ren/csv/o.csv")

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/RRDAIRight.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (17,20,23,49,55,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/RRDAINoNeg.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (15,18,21,47,53,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1 = df[(df.CreditScore > 209) & df['CreditRating'].str.contains('AA')]

# %%
df1.to_csv("D:/Nikkidata/ren/csv/AA.csv")

# %%
df21 = df[(df.CreditScore < 210) & (df.CreditScore > 179) & df['CreditRating'].str.contains('A') ]

# %%
df2 = df21[~df21['CreditRating'].str.contains('AA') ]

# %%
df2.to_csv("D:/Nikkidata/ren/csv/A.csv")

# %%
df3 = df[(df.CreditScore > 149) & df['CreditRating'].str.contains('B') & (df.CreditScore < 180) ]

# %%
df3.to_csv("D:/Nikkidata/ren/csv/B.csv")

# %%
df4 = df[(df.CreditScore > 129) & df['CreditRating'].str.contains('C') & (df.CreditScore < 150) ]

# %%
df4.to_csv("D:/Nikkidata/ren/csv/C.csv")

# %%
df5 = df[(df.CreditScore > 109) & df['CreditRating'].str.contains('D') & (df.CreditScore < 130) ]

# %%
df5.to_csv("D:/Nikkidata/ren/csv/D.csv")

# %%
df6 = df[(df.CreditScore > 99) & df['CreditRating'].str.contains('E') & (df.CreditScore < 110) ]

# %%
df6.to_csv("D:/Nikkidata/ren/csv/E.csv")

# %%
df7 = df[(df.CreditScore < 100) & df['CreditRating'].str.contains('HR') & (df.CreditScore >= 0)]

# %%
df7.to_csv("D:/Nikkidata/ren/csv/HR.csv")

# %%
dfa = pd.read_csv("D:/Nikkidata/ren/csv/AA.csv")
dfb = pd.read_csv("D:/Nikkidata/ren/csv/A.csv")
dfc = pd.read_csv("D:/Nikkidata/ren/csv/B.csv")
dfd = pd.read_csv("D:/Nikkidata/ren/csv/C.csv")
dfe = pd.read_csv("D:/Nikkidata/ren/csv/D.csv")
dff = pd.read_csv("D:/Nikkidata/ren/csv/E.csv")
dfg = pd.read_csv("D:/Nikkidata/ren/csv/HR.csv")

frames = [dfa,dfb,dfc,dfd,dfe,dff,dfg]
all_csv = pd.concat(frames)
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (16,19,22,48,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
all_csv.to_csv("D:/Nikkidata/ren/csv/RRDAIRight.csv")

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/NewFolder2/RRDai.csv")
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7,13,16,19,45,51,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df[(df.CreditScore < 500)]

# %%
df1 = df[(df.CreditScore < 0)]

# %%
df1.to_csv("D:/Nikkidata/ren/csv/negative.csv")

# %%
df2 = df1[df1['CreditRating'].str.contains('HR')]

# %%
df2['CreditScore'] = (-1)*df2.CreditScore
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_6496/1904382653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['CreditScore'] = (-1)*df2.CreditScore

# %%
df2.to_csv("D:/Nikkidata/ren/csv/negativeHR.csv")

# %%
df3 = df[(df.CreditScore >= 0)]

# %%
df4 = df3[(df3.CreditScore < 500)]

# %%
df4.describe()
# Out:
#                  ID     ProjectNo     BidAmount           APR  \
# count  8.207929e+06  8.207929e+06  8.207929e+06  8.207929e+06
# mean   4.354758e+06  5.579119e+06  1.578465e+04  1.080156e+01
# std    2.387186e+06  2.668728e+06  3.895297e+04  1.250488e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  3.000000e+00
# 25%    2.313286e+06  3.515783e+06  1.000000e+03  1.020000e+01
# 50%    4.365268e+06  5.567765e+06  2.300000e+03  1.020000e+01
# 75%    6.417250e+06  7.768069e+06  6.000000e+03  1.200000e+01
# max    8.469232e+06  1.067800e+07  3.000000e+06  2.440000e+01
#
#        RepaymentPeriod       Bidders  RemainningPeriods        UserNo  \
# count     8.207929e+06  8.207929e+06       8.207929e+06  8.207929e+06
# mean      1.180668e+01  1.929968e+01       6.558392e+00  1.463259e+07
# std       9.522779e+00  5.955267e+01       5.967810e+00  4.657609e+06
# min       1.000000e+00  0.000000e+00       0.000000e+00  6.000000e+00
# ...

# %%
df4.to_csv("D:/Nikkidata/ren/csv/Notnegative.csv")

# %%
dfa = pd.read_csv("D:/Nikkidata/ren/csv/negativeHR.csv")
dfb = pd.read_csv("D:/Nikkidata/ren/csv/Notnegative.csv")
frames = [dfa,dfb]
all_csv = pd.concat(frames)
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (8,14,17,20,46,52,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
all_csv.to_csv("D:/Nikkidata/ren/csv/RRDAINoNeg.csv")

# %%
rat_mapping={'AA': 1, 'A': 2, 'B': 3, 'C': 4, 'D': 5, 'E': 6, 'HR': 7}
df['CreditRating'] = df['CreditRating'].map(rat_mapping)

# %%
Pro_mapping={'已还清': 1, '还款中': 2, '已流标': 3, '已垫付': 4}
df['ProjectStatus'] = df['ProjectStatus'].map(Pro_mapping)

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('CreditRating', 'CreditScore', 
           data = df, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditRating vs CreditScore', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df1 = df[df['ProjectStatus'].isin([4]) | df['ProjectStatus'].isin([1]) ]

# %%
import seaborn as sns
sns.set_context(font_scale=2)

plt.figure(figsize=(30,20))

# Linear Plot of CreditRating vs CreditScore
sns.lmplot('CreditRating', 'CreditScore', 
           data = df1, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditRating vs CreditScore', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df2 = df[df['ProjectStatus'].isin([1])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8456/482564625.py in <module>
# ----> 1 df2 = df[df['ProjectStatus'].isin([1])]
#
# NameError: name 'df' is not defined

# %%
df['CreditRating'].value_counts()
# Out:
# 2    7195935
# 7     329788
# 5       9827
# 6       8149
# 4       2408
# 1       2031
# 3       1241
# Name: CreditRating, dtype: int64

# %%
df['ProjectStatus'].value_counts()
# Out:
# 1    3676585
# 2    3539394
# 3     329658
# 4       3742
# Name: ProjectStatus, dtype: int64

# %%
df3 = df[df['ProjectStatus'].isin([4])]

# %%
df3['CreditRating'].value_counts()
# Out:
# 7    3925
# 6     156
# 5      64
# 4      18
# 2       8
# 3       4
# 1       1
# Name: CreditRating, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='PubTime',y='CreditScore',data=df1,hue='ProjectStatus')
plt.savefig('CreditScoreTime.jpg', dpi=300)

# %%
import matplotlib.pyplot as plt
# Histogram of the CreditScore
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist(df['CreditScore'], bins = 50, edgecolor = 'k');
plt.xlabel('score'); 
plt.ylabel('Number of Borrowers'); 
plt.legend()
plt.title('Distribution of the processed creditscore');
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
dff
# Out:
#      Number  CreditScore
# 0       181        13308
# 1        30        12140
# 2        22         6172
# 3        27         5223
# 4        25         4937
# ..      ...          ...
# 212     191            3
# 213     198            3
# 214     177            2
# 215     163            1
# 216     243            1
#
# [217 rows x 2 columns]

# %%
a = df['CreditScore'].value_counts()

# %%
a.to_csv("D:/Nikkidata/ren/csv/CreditScore1.csv")

# %%
dff = pd.read_excel("D:/Nikkidata/ren/csv/CreditScore1.xlsx")

# %%
y = dff['CreditScore']
x = dff['Number']
plt.scatter(x,y,s=10)

# %%
Pro_mapping={'已还清': 1, '还款中': 2, '已流标': 3, '已垫付': 4}
df['ProjectStatus'] = df['ProjectStatus'].map(Pro_mapping)

# %%
df1 = df[df['ProjectStatus'].isin([4]) | df['ProjectStatus'].isin([1]) ]

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='ID',y='CreditScore',data=df1,hue='ProjectStatus')
plt.savefig('CreditScore14.jpg', dpi=300)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('CreditScore', 'APR', 
           data = df, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditScore vs APR', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(30,15))


# Linear Plot of CreditScore vs APR
sns.lmplot('CreditScore', 'APR', 
           data = df1, hue = 'ProjectStatus', 
           scatter_kws={'alpha': 0.8, 's': 32}, fit_reg=False, 
           size = 12, aspect = 1.2)

plt.title('CreditScore14 vs APR', size = 24)
plt.legend()
# Out:
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mb95424\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df['CreditRating'].value_counts()
# Out:
# 2    7195935
# 7     582969
# 5       9827
# 6       8149
# 4       2408
# 1       2031
# 3       1241
# Name: CreditRating, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.scatterplot(x='PubTime',y='CreditScore',data=df,hue='ProjectStatus')
plt.savefig('CreditScoreTime.jpg', dpi=300)
