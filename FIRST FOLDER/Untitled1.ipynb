# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from CreditScoreModel.LogisticScoreCard import logistic_score_card
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.pylabtools import figsize
import seaborn as sns
sns.set_context(font_scale=2)

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/book2.csv")

# %%
import matplotlib.pyplot as plt
# Histogram of the CreditScore

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
plt.figure()
plt.hist(df['CreditScore'].dropna(), bins = 100, edgecolor = 'k');
plt.xlabel('score'); plt.ylabel('Number of Borrowers'); 
plt.legend()
plt.figure()
plt.hist(df['score'].dropna(), bins = 100, edgecolor = 'k');
plt.legend()
plt.title('score Distribution');
plt.show()
# Out:
# 2021 15:13:59 WARNING No handles with labels found to put in legend.
# 2021 15:13:59 WARNING No handles with labels found to put in legend.

# %%
figsize(30, 10)
x = df['ID']

y1 = df['score']

y2 = df['CreditScore']

plt.ylabel('score')
plt.xlabel('ID')

plt.scatter(x,y1, label='Success')
plt.scatter(x,y2, label='Fail')
plt.legend()
plt.show()

# %%
df = pd.read_csv("D:/Nikkidata/ren/csv/score1.csv")

# %%
df['ProjectStatus'].value_counts()
# Out:
# 1    4890
# 0    4148
# Name: ProjectStatus, dtype: int64

# %%
df1 = pd.read_csv("D:/Nikkidata/ren/csv/1.csv")

# %%
frames = [df, df1]

# %%
result_csv = pd.concat(frames)

# %%
result_csv.head()
# Out:
#    CertifiMark  BidAmount   APR  GuaranteeWays  ProjectStatus  Sex  \
# 0          1.0     3900.0  20.1            1.0            0.0  2.0
# 1          1.0     3050.0  19.8            1.0            0.0  2.0
# 2          1.0     4000.0  21.4            1.0            0.0  2.0
# 3          1.0     3000.0  22.4            1.0            0.0  2.0
# 4          1.0     3000.0  15.0            1.0            0.0  2.0
#
#    CreditScore CreditRating   Age  Education  ...  WorkingHour  OthDebt  \
# 0         80.0           HR  48.0        1.0  ...          1.0      1.0
# 1         80.0           HR  48.0        1.0  ...          1.0      1.0
# 2         80.0           HR  33.0        1.0  ...          2.0      1.0
# 3         80.0           HR  35.0        2.0  ...          2.0      1.0
# 4         80.0           HR  32.0        2.0  ...          2.0      1.0
#
#    APRscore  BidAmountscore  CompanySizescore  Educationscore  \
# 0       NaN             NaN               NaN             NaN
# ...

# %%
df = df.dropna(subset=['OthDebt'])

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI_NUMover2.csv", index =0)

# %%
dfa = df.drop(index=[27])

# %%
df.dtypes
# Out:
# CertifiMark            object
# BidAmount               int64
# APR                   float64
# GuaranteeWays          object
# RepaySource            object
# Sex                    object
# CreditScore             int64
# CreditRating           object
# Age                   float64
# Education              object
# MaritalStatus          object
# LoanNumbers             int64
# Credits                 int64
# DefaultAmount         float64
# SuccessfulNum           int64
# TotalAmount             int64
# DefaultTimes          float64
# PaidOffTimes            int64
# SeriousDefaultLoan      int64
# Income                 object
# hasHouse               object
# houseLoan              object
# hasCar                 object
# carLoan                object
# CompanySize            object
# WorkingHour            object
# OthDebt                object
# dtype: object

# %%
df = df.drop(columns=['CompanyIndustry','JobType','CompanyPosition','ResidenceCity','CloseTime','ProjectStatus','Bidders','RepaymentPeriod','PubTime',])

# %%
df.head()
# Out:
#    CertifiMark  BidAmount  APR  RepaymentPeriod  GuaranteeWays  RepaySource  \
# 0            1       5000   12                3              0          0.0
# 1            1       3000    5                6              1          0.0
# 2            1       3000   10                3              1          0.0
# 3            1       5000   18               18              1          0.0
# 4            1       3050    8                3              0          0.0
#
#    Sex  CreditScore CreditRating  Age  ...  PaidOffTimes  SeriousDefaultLoan  \
# 0    2          210           AA   33  ...             2                   0
# 1    2          210           AA   34  ...            23                   0
# 2    1          210           AA   40  ...             3                   0
# 3    2          210           AA   33  ...             2                   0
# 4    1          110            D   31  ...             0                   0
#
# ...

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI_NUMover1.csv", index =0)

# %%
df['OthDebt'] = df['OthDebt'].replace(2, 1)

# %%
df = df.drop(columns=['CreditScore','CreditRating'])

# %%
df = df.drop_duplicates()

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI1.csv", index =0)

# %%
df = df.drop(columns=['Bidders','Credits','CloseTime','PubTime','ResidenceCity','JobType','CompanyIndustry','CompanyPosition'])

# %%
df.dtypes
# Out:
# CertifiMark            object
# BidAmount               int64
# APR                   float64
# RepaymentPeriod         int64
# GuaranteeWays          object
# RepaySource            object
# ProjectStatus          object
# Sex                    object
# CreditScore             int64
# CreditRating           object
# Age                   float64
# Education              object
# MaritalStatus          object
# LoanNumbers             int64
# DefaultAmount         float64
# SuccessfulNum           int64
# TotalAmount             int64
# DefaultTimes          float64
# PaidOffTimes            int64
# SeriousDefaultLoan      int64
# Income                 object
# hasHouse               object
# houseLoan              object
# hasCar                 object
# carLoan                object
# CompanySize            object
# WorkingHour            object
# OthDebt                object
# dtype: object

# %%
df = df.drop(columns=['ProjectStatus'])

# %%
house_mapping={'有房产': 1,'无房产': 0}
df['hasHouse'] = df['hasHouse'].map(house_mapping)

# %%
hloan_mapping={'有房贷': 1,'无房贷': 0}
df['houseLoan'] = df['houseLoan'].map(hloan_mapping)

# %%
Car_mapping={'有车产': 1, '无车产': 0}
df['hasCar'] = df['hasCar'].map(Car_mapping)

# %%
cloan_mapping={'有车贷': 1,'无车贷': 0}
df['carLoan'] = df['carLoan'].map(cloan_mapping)

# %%
edu_mapping={'高中或以下': 1, '大专': 2,'本科': 3, '研究生或以上': 4}
df['Education'] = df['Education'].map(edu_mapping)

# %%
Mar_mapping={'丧偶': 1, '离异': 2, '未婚': 3, '已婚': 4}
df['MaritalStatus'] = df['MaritalStatus'].map(Mar_mapping)

# %%
com_mapping={'10人以下': 1, '10-100人': 2, '100-500人': 3, '500人以上': 4}
df['CompanySize'] = df['CompanySize'].map(com_mapping)

# %%
wor_mapping={'1年（含）以下': 1, '1-3年（含）': 2, '3-5年（含）': 3, '5年以上': 4}
df['WorkingHour'] = df['WorkingHour'].map(wor_mapping)

# %%
Inc_mapping={'1000元以下': 1, '2000元以下': 1, '2000-5000元': 1, '5000-10000元': 2,'10000-20000元': 3,'20000-50000元': 4,'50000元以上': 5}
df['Income'] = df['Income'].map(Inc_mapping)

# %%
df.head()
# Out:
#    CertifiMark  BidAmount  APR  RepaymentPeriod  GuaranteeWays  RepaySource  \
# 0            1       5000   12                3              0          0.0
# 1            1       3000    5                6              1          0.0
# 2            1       3000   10                3              1          0.0
# 3            1       5000   18               18              1          0.0
# 4            1       3050    8                3              0          0.0
#
#    Sex  CreditScore CreditRating  Age  ...  SeriousDefaultLoan  Income  \
# 0    2          210           AA   33  ...                   0     2.0
# 1    2          210           AA   34  ...                   0     4.0
# 2    1          210           AA   40  ...                   0     4.0
# 3    2          210           AA   33  ...                   0     2.0
# 4    1          110            D   31  ...                   0     0.0
#
#    hasHouse  houseLoan  hasCar  carLoan  CompanySize  WorkingHour  OthDebt  \
# ...

# %%
sex_mapping={'男': 2, '女': 1}
df['Sex'] = df['Sex'].map(sex_mapping)

# %%
gua_mapping={'用户利益保障机制': 1, '暂无': 0}
df['GuaranteeWays'] = df['GuaranteeWays'].map(gua_mapping)

# %%
cer_mapping={'信用认证标': 1, '实地认证标': 2, '机构担保标': 3, '智能理财标': 4}
df['CertifiMark'] = df['CertifiMark'].map(cer_mapping)

# %%
df['OthDebt'].value_counts()
# Out:
# 1.0    6390537
# 0.0    1497958
# 2.0     580479
# Name: OthDebt, dtype: int64

# %%
Rep_mapping={'其他': 1, '经营收入': 2, '财产收入': 3, '工资': 4,'工资收入': 4}
df['RepaySource'] = df['RepaySource'].map(Rep_mapping)

# %%
df['RepaySource'] = df['RepaySource'].fillna(0)

# %%
df['WorkingHour'] = df['WorkingHour'].fillna(0)

# %%
oth_mapping={'有': 1, '无': 0, '未获取': 2}
df['OthDebt'] = df['OthDebt'].map(oth_mapping)

# %%
df['APR'] = df['APR'].astype('int')

# %%
df['Age'] = df['Age'].astype('int')

# %%
df['DefaultTimes'] = df['DefaultTimes'].astype('int')
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_7280/747914274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DefaultTimes'] = df['DefaultTimes'].astype('int')

# %%
df = df.rename(columns={'WorkingHour\t':'WorkingHour'})

# %%
df=df.dropna(subset=['DefaultTimes'])

# %%
null_all= df.isnull().sum()

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI_NUM.csv", index =0)

# %%
a_null = df[pd.isnull(df['houseLoan'])]

# %%
b_null = df[pd.isnull(df['OthDebt'])]

# %%
print(b_null)
# Out:
# Empty DataFrame
# Columns: [CertifiMark, BidAmount, APR, RepaymentPeriod, GuaranteeWays, RepaySource, Sex, CreditScore, CreditRating, Age, Education, MaritalStatus, LoanNumbers, DefaultAmount, SuccessfulNum, TotalAmount, DefaultTimes, PaidOffTimes, SeriousDefaultLoan, Income, hasHouse, houseLoan, hasCar, carLoan, CompanySize, WorkingHour, OthDebt, WorkingHour]
# Index: []
#
# [0 rows x 28 columns]

# %%
b_null = df[df['OthDebt'].isin([2])]

# %%
df['carLoan'] = df['carLoan'].fillna(0)
# Out:
# C:\Users\mb95424\AppData\Local\Temp/ipykernel_7280/3437669151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['carLoan'] = df['carLoan'].fillna(0)

# %%
print(df['OthDebt'] )
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 8468975    2.0
# 8468976    2.0
# 8468977    2.0
# 8468978    2.0
# 8468979    2.0
# Name: OthDebt, Length: 8468974, dtype: float64

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI_NUMover.csv", index =0)

# %%
df.to_csv("D:/Nikkidata/ren/csv/RRDAI_spss.csv", index =0)

# %%
df.head()
# Out:
#    CertifiMark  BidAmount  APR  RepaymentPeriod  GuaranteeWays  RepaySource  \
# 0            1       5000   12                3              0          0.0
# 1            1       3000    5                6              1          0.0
# 2            1       3000   10                3              1          0.0
# 3            1       5000   18               18              1          0.0
# 4            1       3050    8                3              0          0.0
#
#    Sex  Age  Education  MaritalStatus  ...  SeriousDefaultLoan  Income  \
# 0    2   33        4.0            3.0  ...                   0     2.0
# 1    2   34        3.0            3.0  ...                   0     4.0
# 2    1   40        4.0            3.0  ...                   0     4.0
# 3    2   33        4.0            3.0  ...                   0     2.0
# 4    1   31        3.0            3.0  ...                   0     0.0
#
#    hasHouse  houseLoan  hasCar  carLoan  CompanySize  WorkingHour  OthDebt  \
# ...

# %%
import random

# %%
df=df.dropna(subset=['Age'])

# %%
dq=df.dropna(subset=['MaritalStatus'])

# %%
dfa = dq[dq['ProjectStatus'].str.contains('已还清')|dq['ProjectStatus'].str.contains('还款中')|dq['ProjectStatus'].str.contains('已垫付')]

# %%
dfb = dq[dq['ProjectStatus'].str.contains('已流标')]

# %%
dq['APR'] = dq['APR'].astype('int')
dq['MaritalStatus'] = dq['MaritalStatus'].astype('int')

# %%
group1 = dfa['APR'].groupby(dfa['MaritalStatus']).mean()

# %%
print(group1)

# %%
group2 = dfb['APR'].groupby(dfb['MaritalStatus']).mean()

# %%
print(group1)

# %%
plt.ylabel('APR')
plt.xlabel('MaritalStatus')
plt.plot(group1,'.-', label='Success')
plt.plot(group2,'.-', label='Fail')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
x = ['男','女']
y1 = ['37259','70788']
y2 = ['4909892','2372177']
plt.ylabel('Number')
plt.xlabel('Sex')
plt.figure(1)
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,2)
plt.sca(ax1)
plt.plot(x,y1, '.-', label='Fail')
plt.sca(ax2)
plt.plot(x,y2, '.-', label='Success')
plt.legend()
plt.show()

# %%
y2 = ['4909892','2372177']

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
x = ['男','女']

y1 = ['男','女']
y2 = ['男','女']

plt.ylabel('APR')
plt.xlabel('Sex')
plt.figure(1)
ax1 = plt.subplot(2,2,1)
ax2 = plt.subplot(2,2,2)
ax3 = plt.subplot(2,1,2)
plt.sca(ax1)
plt.plot(x,y1, '.-', label='Success')
plt.sca(ax2)
plt.plot(x,y2, '.-', label='Fail')
plt.sca(ax3)
plt.plot(x,y1, '.-', label='Success')
plt.plot(x,y2, '.-', label='Fail')
plt.legend()
plt.savefig('D:/Nikkidata/ren/csv/Sex_APR.png')
plt.show()
